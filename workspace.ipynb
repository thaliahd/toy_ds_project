# %%
# loading libraries

library(tidyverse)
library(testthat)
library(digest)
library(repr)
library(tidymodels)
library(GGally)
library(ISLR)
library(forcats)
library(broom)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ ggplot2 3.3.2     ✔ purrr   0.3.4
# ✔ tibble  3.0.3     ✔ dplyr   1.0.2
# ✔ tidyr   1.1.2     ✔ stringr 1.4.0
# ✔ readr   1.3.1     ✔ forcats 0.5.0
#
# Warning message:
# “package ‘ggplot2’ was built under R version 4.0.1”
# Warning message:
# “package ‘tibble’ was built under R version 4.0.2”
# Warning message:
# “package ‘tidyr’ was built under R version 4.0.2”
# Warning message:
# “package ‘dplyr’ was built under R version 4.0.2”
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
#
# Attaching package: ‘testthat’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     matches
#
#
# The following object is masked from ‘package:purrr’:
#
#     is_null
#
#
# The following object is masked from ‘package:tidyr’:
#
#     matches
#
#
# Warning message:
# ...

# %%
?step_upsample
# Out:
# step_upsample             package:recipes              R Documentation
#
# e
#
# n:
#
#      ‘step_upsample’ is now available as ‘themis::step_upsample()’.
#      This function creates a _specification_ of a recipe step that will
#      replicate rows of a data set to make the occurrence of levels in a
#      specific factor level equal.
#
# e:
#
#      step_upsample(
#        recipe,
#        ...,
#        over_ratio = 1,
#        ratio = NA,
#        role = NA,
#        trained = FALSE,
#        column = NULL,
#        target = NA,
#        skip = TRUE,
#        seed = sample.int(10^5, 1),
#        id = rand_id("upsample")
#      )
#
#      ## S3 method for class 'step_upsample'
#      tidy(x, ...)
#
# s:
#
#   recipe: A recipe object. The step will be added to the sequence of
#           operations for this recipe.
#
#      ...: One or more selector functions to choose which variable is
#           used to sample the data. See ‘selections()’ for more details.
# ...
